# %%
import datetime as dt
from dateutil.relativedelta import relativedelta

from date.daycount import year_fraction_actact

# %%
d1 = dt.date(2025,2,11)
d2 = dt.date(2025,6,14)

# %%
abs(d1.year - d2.year)
# Out:
# 0

# %%
year_fraction_actact(d1, d2)
# Out:
# 0.336986301369863
